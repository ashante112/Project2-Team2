# %%
import pandas as pd
df = pd.read_csv('GVP_Volcano_List.csv', usecols=['Volcano Number', 'Volcano Name', 'Primary Volcano Type', 'Last Eruption Year', 'Country', 'Region', 'Subregion', 'Latitude','Latitude','Elevation','Tectonic Settings', 'Evidence Category','Major Rock 1'])

# %%
df.head(5)
# Out:
#    Volcano Number   Volcano Name Primary Volcano Type  Last Eruption Year  \
# 0          290390          Alaid        Stratovolcano                2018
# 1          221060  Alu-Dalafilla      Fissure vent(s)                2008
# 2          257040         Ambrym   Pyroclastic shield                2018
# 3          284200       Anatahan        Stratovolcano                2008
# 4          283110      Asamayama              Complex                2019
#
#          Country                   Region                          Subregion  \
# 0         Russia            Kuril Islands                      Kuril Islands
# 1       Ethiopia       Africa and Red Sea  Africa (northeastern) and Red Sea
# 2        Vanuatu  Melanesia and Australia                            Vanuatu
# 3  United States  Japan, Taiwan, Marianas  Izu, Volcano, and Mariana Islands
# 4          Japan  Japan, Taiwan, Marianas                             Honshu
#
# ...
